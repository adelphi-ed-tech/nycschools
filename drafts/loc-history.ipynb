# %%
import pandas as pd
# 2019-2020
# https://data.cityofnewyork.us/Education/2019-2020-School-Locations/wg9x-4ke6/about_data
url = "https://data.cityofnewyork.us/resource/wg9x-4ke6.json?$limit=1000000"
url = "https://data.cityofnewyork.us/resource/a94k-kjys.csv"
url = "https://data.cityofnewyork.us/resource/c7ru-d68s.csv?$limit=1000000"
df = pd.read_csv(url)
df["ay"] = df.year.str[:4]
df.ay.unique()
# Out:
# array(['2017', '2018', '2019', '2020', '2021'], dtype=object)

# %%
from nycschools import snapshot as snap

df = snap.load_snapshots()

# info = pd.read_csv("snapshots/school_info.csv")
# doe = pd.read_csv("snapshots/doe_school_list.csv")
# a = set(info.dbn)
# b = set(doe.dbn)
# b
df
# Out:
#          dbn                                 location_name_long  \
# 0     01M134                           P.S. 134 Henrietta Szold
# 1     02M150                                           P.S. 150
# 2     02M151                         Yorkville Community School
# 3     01M315                  The East Village Community School
# 4     01M361                     The Children's Workshop School
# ...      ...                                                ...
# 7719  84M382                               DREAM Charter School
# 7720  84M373                    Zeta Charter Schools - Inwood 1
# 7721  84M284  Harlem Children's Zone Promise Academy 1 Chart...
# 7722  25Q219                              P.S. 219 Paul Klapper
# 7723  25Q185                          J.H.S. 185 Edward Bleeker
#
#      abbr_school_type                address all_es_admissionsmethods  \
# 0                 NaN      293 East Broadway            Choice School
# ...
