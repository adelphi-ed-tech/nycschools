# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.map import Element
import seaborn as sns
from IPython.display import Markdown as md
from IPython.display import display, HTML

from nycschools import schools, geo, ui

# load all of the data and clean it up
loc = geo.load_school_locations()
districts = geo.load_districts()
df = schools.load_school_demographics()

df = df[df.ay == df.ay.max()]


# merge school locations and demographics
# get only the demo columns that aren't in locations already
cols = ["dbn"] + list(set(df.columns) - set(loc.columns))
data = loc.merge(df[cols], on="dbn", how="inner")
data
# Out:
#          dbn    zip geo_district  district        x       y  \
# 0     02M212  10036            2         2   987390  216649
# 1     29Q034  11429           29        29  1056968  198417
# 2     17K091  11203           17        17  1000700  180396
# 3     31R455  10312           31        31   930477  131756
# 4     07X522  10451            7         7  1006407  237542
# ...      ...    ...          ...       ...      ...     ...
# 2699  15K124  11215           15        15   986852  182452
# 2700  28Q161  11419           28        28  1033868  190873
# 2701  08X100  10473            8         8  1022234  238985
# 2702  84M523  10024            3        84   991316  225688
# 2703  29Q118  11412           29        29  1049342  195552
#
#       administrative_district_code  administrative_district_name  \
# 0                              2.0  COMMUNITY SCHOOL DISTRICT 02
# 1                             29.0  COMMUNITY SCHOOL DISTRICT 29
# 2                             17.0  COMMUNITY SCHOOL DISTRICT 17
# 3                             31.0  COMMUNITY SCHOOL DISTRICT 31
# 4                              7.0                           NaN
# ...                            ...                           ...
# 2699                          15.0  COMMUNITY SCHOOL DISTRICT 15
# 2700                          28.0  COMMUNITY SCHOOL DISTRICT 28
# 2701                           8.0  COMMUNITY SCHOOL DISTRICT 08
# 2702                          84.0     OFFICE OF CHARTER SCHOOLS
# 2703                          29.0  COMMUNITY SCHOOL DISTRICT 29
#
#               beds  borough_block_lot  ...  grade_8  grade_7  \
# 0     310200010212       1.010380e+09  ...        0        0
# 1     342900010034       4.111510e+09  ...        0        0
# 2     331700010091       3.047940e+09  ...        0        0
# 3     353100011455       5.066130e+09  ...        0        0
# 4     320700011522       2.024110e+09  ...        0        0
# ...            ...                ...  ...      ...      ...
# 2699  331500010124       3.010340e+09  ...        0        0
# 2700  342800010161       4.094910e+09  ...        0        0
# 2701  320800010100       2.036410e+09  ...        0        0
# 2702  310300861008       1.012150e+09  ...       78      115
# 2703  342900010118       4.109260e+09  ...        0        0
#
#       missing_race_ethnicity_data_pct grade_2  poverty_n female_pct  grade_k  \
# 0                               0.000      44         86      0.506       52
# 1                               0.000      95        475      0.522       64
# 2                               0.000      23        172      0.516       18
# 3                               0.009       0       1550      0.510        0
# 4                               0.000       0        288      0.147        0
# ...                               ...     ...        ...        ...      ...
# 2699                            0.000      34        182      0.505       39
# 2700                            0.000      77        453      0.509       84
# 2701                            0.000      74        456      0.502       70
# 2702                            0.000      90        406      0.512       95
# 2703                            0.002      55        298      0.521       68
#
#       grade_10 grade_12 grade_9
# 0            0        0       0
# 1            0        0       0
# 2            0        0       0
# 3          962      880    1010
# 4           77       57     102
# ...        ...      ...     ...
# 2699         0        0       0
# 2700         0        0       0
# 2701         0        0       0
# 2702         0        0       0
# 2703         0        0       0
#
# [2704 rows x 87 columns]
