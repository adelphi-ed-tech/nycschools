# %% [markdown]
# Load the 2007 Common Core of Data
# ===================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

import scipy

from IPython.display import Markdown as md, HTML
from nycschools import schools, geo, ui, class_size

# %%
pd.read_csv("/home/mxc/Downloads/ccd_sch_129_2223_w_1a_083023/ccd-school-universe.csv")
# Out:
#        SCHOOL_YEAR  FIPST            STATENAME  ST  \
# 0        2022-2023      1              ALABAMA  AL
# 1        2022-2023      1              ALABAMA  AL
# 2        2022-2023      1              ALABAMA  AL
# 3        2022-2023      1              ALABAMA  AL
# 4        2022-2023      1              ALABAMA  AL
# ...            ...    ...                  ...  ..
# 100566   2022-2023     78  U.S. VIRGIN ISLANDS  VI
# 100567   2022-2023     78  U.S. VIRGIN ISLANDS  VI
# 100568   2022-2023     78  U.S. VIRGIN ISLANDS  VI
# 100569   2022-2023     78  U.S. VIRGIN ISLANDS  VI
# 100570   2022-2023     78  U.S. VIRGIN ISLANDS  VI
#
#                                  SCH_NAME  STATE_AGENCY_NO  UNION ST_LEAID  \
# 0               Albertville Middle School                1    NaN   AL-101
# 1                 Albertville High School                1    NaN   AL-101
# 2         Albertville Intermediate School                1    NaN   AL-101
# 3           Albertville Elementary School                1    NaN   AL-101
# 4       Albertville Kindergarten and PreK                1    NaN   AL-101
# ...                                   ...              ...    ...      ...
# 100566         LOCKHART ELEMENTARY SCHOOL                1    NaN   VI-001
# 100567    ULLA F MULLER ELEMENTARY SCHOOL                1    NaN   VI-001
# 100568    YVONNE BOWSKY ELEMENTARY SCHOOL                1    NaN   VI-001
# 100569         CANCRYN JUNIOR HIGH SCHOOL                1    NaN   VI-001
# 100570       BERTHA BOSCHULTE JUNIOR HIGH                1    NaN   VI-001
#
#           LEAID     ST_SCHID       NCESSCH    SCHID SHARED_TIME NSLP_STATUS  \
# 0        100005  AL-101-0010   10000500870   100870          No   NSLPWOPRO
# 1        100005  AL-101-0020   10000500871   100871          No   NSLPWOPRO
# 2        100005  AL-101-0110   10000500879   100879          No   NSLPWOPRO
# 3        100005  AL-101-0200   10000500889   100889          No   NSLPWOPRO
# 4        100005  AL-101-0035   10000501616   101616          No   NSLPWOPRO
# ...         ...          ...           ...      ...         ...         ...
# 100566  7800030    VI-001-15  780003000024  7800024          No    NSLPPRO1
# 100567  7800030    VI-001-17  780003000026  7800026          No    NSLPPRO1
# 100568  7800030    VI-001-23  780003000027  7800027          No    NSLPPRO1
# 100569  7800030    VI-001-25  780003000033  7800033          No    NSLPPRO1
# 100570  7800030     VI-001-9  780003000034  7800034          No    NSLPPRO1
#
#                                          NSLP_STATUS_TEXT     VIRTUAL  \
# 0       Yes participating without using any Provision ...  NOTVIRTUAL
# 1       Yes participating without using any Provision ...  NOTVIRTUAL
# 2       Yes participating without using any Provision ...  NOTVIRTUAL
# 3       Yes participating without using any Provision ...  NOTVIRTUAL
# 4       Yes participating without using any Provision ...  NOTVIRTUAL
# ...                                                   ...         ...
# 100566                              Yes under Provision 1  NOTVIRTUAL
# 100567                              Yes under Provision 1  NOTVIRTUAL
# 100568                              Yes under Provision 1  NOTVIRTUAL
# 100569                              Yes under Provision 1  NOTVIRTUAL
# 100570                              Yes under Provision 1  NOTVIRTUAL
#
#                   VIRTUAL_TEXT
# 0       No virtual instruction
# 1       No virtual instruction
# 2       No virtual instruction
# 3       No virtual instruction
# 4       No virtual instruction
# ...                        ...
# 100566  No virtual instruction
# 100567  No virtual instruction
# 100568  No virtual instruction
# 100569  No virtual instruction
# 100570  No virtual instruction
#
# [100571 rows x 17 columns]

# %%
# load common core of data for 2007-2008 to match the data in the journal article
# description of columns: https://nces.ed.gov/ccd/pdf/psu071bgen.pdf
ccd = pd.read_csv("_data/ccod-2007.csv")
ccd.head()

print(list(ccd.columns))
[c for c in ccd.columns if "ZIP" in c]
ccd[ccd["MZIP07"] == "10001"]

ccd["zip"] = ccd["MZIP07"].apply(lambda x: f"{x:05}")
ccd["zip"].unique()
# Out:
# ['NCESSCH', 'FIPST', 'LEAID', 'school_id', 'STID07', 'SEASCH07', 'LEANM07', 'school_name', 'phone', 'MSTREE07', 'MCITY07', 'MSTATE07', 'MZIP07', 'MZIP407', 'LSTREE07', 'city', 'state', 'zip', 'LZIP407', 'TYPE07', 'STATUS07', 'ULOCAL07', 'latitude', 'longitude', 'CONUM07', 'county', 'FTE07', 'CDCODE07', 'GSLO07', 'GSHI07', 'LEVEL07', 'TITLEI07', 'STITLI07', 'MAGNET07', 'CHARTR07', 'SHARED07', 'FRELCH07', 'REDLCH07', 'TOTFRL07', 'MIGRNT07', 'PK07', 'AMPKM07', 'AMPKF07', 'ASPKM07', 'ASPKF07', 'HIPKM07', 'HIPKF07', 'BLPKM07', 'BLPKF07', 'WHPKM07', 'WHPKF07', 'KG07', 'AMKGM07', 'AMKGF07', 'ASKGM07', 'ASKGF07', 'HIKGM07', 'HIKGF07', 'BLKGM07', 'BLKGF07', 'WHKGM07', 'WHKGF07', 'G0107', 'AM01M07', 'AM01F07', 'AS01M07', 'AS01F07', 'HI01M07', 'HI01F07', 'BL01M07', 'BL01F07', 'WH01M07', 'WH01F07', 'G0207', 'AM02M07', 'AM02F07', 'AS02M07', 'AS02F07', 'HI02M07', 'HI02F07', 'BL02M07', 'BL02F07', 'WH02M07', 'WH02F07', 'G0307', 'AM03M07', 'AM03F07', 'AS03M07', 'AS03F07', 'HI03M07', 'HI03F07', 'BL03M07', 'BL03F07', 'WH03M07', 'WH03F07', 'G0407', 'AM04M07', 'AM04F07', 'AS04M07', 'AS04F07', 'HI04M07', 'HI04F07', 'BL04M07', 'BL04F07', 'WH04M07', 'WH04F07', 'G0507', 'AM05M07', 'AM05F07', 'AS05M07', 'AS05F07', 'HI05M07', 'HI05F07', 'BL05M07', 'BL05F07', 'WH05M07', 'WH05F07', 'G0607', 'AM06M07', 'AM06F07', 'AS06M07', 'AS06F07', 'HI06M07', 'HI06F07', 'BL06M07', 'BL06F07', 'WH06M07', 'WH06F07', 'G0707', 'AM07M07', 'AM07F07', 'AS07M07', 'AS07F07', 'HI07M07', 'HI07F07', 'BL07M07', 'BL07F07', 'WH07M07', 'WH07F07', 'G0807', 'AM08M07', 'AM08F07', 'AS08M07', 'AS08F07', 'HI08M07', 'HI08F07', 'BL08M07', 'BL08F07', 'WH08M07', 'WH08F07', 'G0907', 'AM09M07', 'AM09F07', 'AS09M07', 'AS09F07', 'HI09M07', 'HI09F07', 'BL09M07', 'BL09F07', 'WH09M07', 'WH09F07', 'G1007', 'AM10M07', 'AM10F07', 'AS10M07', 'AS10F07', 'HI10M07', 'HI10F07', 'BL10M07', 'BL10F07', 'WH10M07', 'WH10F07', 'G1107', 'AM11M07', 'AM11F07', 'AS11M07', 'AS11F07', 'HI11M07', 'HI11F07', 'BL11M07', 'BL11F07', 'WH11M07', 'WH11F07', 'G1207', 'AM12M07', 'AM12F07', 'AS12M07', 'AS12F07', 'HI12M07', 'HI12F07', 'BL12M07', 'BL12F07', 'WH12M07', 'WH12F07', 'UG07', 'AMUGM07', 'AMUGF07', 'ASUGM07', 'ASUGF07', 'HIUGM07', 'HIUGF07', 'BLUGM07', 'BLUGF07', 'WHUGM07', 'WHUGF07', 'MEMBER07', 'AM07', 'AMALM07', 'AMALF07', 'ASIAN07', 'ASALM07', 'ASALF07', 'HISP07', 'HIALM07', 'HIALF07', 'BLACK07', 'BLALM07', 'BLALF07', 'WHITE07', 'WHALM07', 'WHALF07', 'TOTETH07', 'PUPTCH07', 'TOTGRD07', 'Unnamed: 224', 'Unnamed: 225', 'Unnamed: 226', 'Unnamed: 227', 'Unnamed: 228']
# /tmp/ipykernel_11415/1042092769.py:3: DtypeWarning: Columns (4,5,8,12,13,17,18,19,20,21,22,23,24,26,27,34,36,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   ccd = pd.read_csv("_data/ccod-2007.csv")
# array(['35220', '36016', '36057', ..., '00830', '00831', '00804'],
#       dtype=object)

# %%
encoding = "latin-1"
cbsa = pd.read_csv("_data/zip07_cbsa06.csv", encoding=encoding)
cbsa.head()
# Out:
# /tmp/ipykernel_11415/2201226099.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   cbsa = pd.read_csv("_data/zip07_cbsa06.csv", encoding=encoding)
#    ZIP5  ZIP4   ZIP9  STATE CODE STATE  COUNTY CODE   COUNTY NAME  CBSA CODE  \
# 0  4841   NaN  04841          23    ME           13   Knox County    40500.0
# 1  4843   NaN  04843          23    ME           13   Knox County    40500.0
# 2  4846   NaN  04846          23    ME           13   Knox County    40500.0
# 3  4847   NaN  04847          23    ME           13   Knox County    40500.0
# 4  4848   NaN  04848          23    ME           27  Waldo County        NaN
#
#      CBSA TITLE                      CBSA LSAD  METRO DIVISION CODE  \
# 0  Rockland, ME  Micropolitan Statistical Area                  NaN
# 1  Rockland, ME  Micropolitan Statistical Area                  NaN
# 2  Rockland, ME  Micropolitan Statistical Area                  NaN
# 3  Rockland, ME  Micropolitan Statistical Area                  NaN
# 4           NaN                            NaN                  NaN
#
#   METRO DIVISION TITLE METRO DIVISION LSAD  CSA CODE CSA TITLE CSA LSAD
# 0                  NaN                 NaN       NaN       NaN      NaN
# 1                  NaN                 NaN       NaN       NaN      NaN
# 2                  NaN                 NaN       NaN       NaN      NaN
# 3                  NaN                 NaN       NaN       NaN      NaN
# 4                  NaN                 NaN       NaN       NaN      NaN

# %%
ny = cbsa[(cbsa["STATE"] == "NY") & (cbsa["COUNTY NAME"] == "New York County")]
ny[["ZIP5","COUNTY NAME","CBSA CODE"]].drop_duplicates().head()
ny["zip"] = ny["ZIP5"].apply(lambda x: f"{x:05}")
ny["zip"].unique()
# Out:
# /tmp/ipykernel_11415/2695792379.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny["zip"] = ny["ZIP5"].apply(lambda x: f"{x:05}")
# array(['10001', '10002', '10003', '10004', '10005', '10006', '10007',
#        '10008', '10009', '10010', '10011', '10012', '10013', '10014',
#        '10016', '10017', '10018', '10019', '10020', '10021', '10022',
#        '10023', '10024', '10025', '10026', '10027', '10028', '10029',
#        '10030', '10031', '10032', '10033', '10034', '10035', '10036',
#        '10037', '10038', '10039', '10040', '10041', '10043', '10044',
#        '10045', '10047', '10048', '10055', '10069', '10072', '10080',
#        '10081', '10082', '10087', '10101', '10102', '10103', '10104',
#        '10105', '10106', '10107', '10108', '10109', '10110', '10111',
#        '10112', '10113', '10114', '10115', '10116', '10117', '10118',
#        '10119', '10120', '10121', '10122', '10123', '10124', '10125',
#        '10126', '10128', '10129', '10130', '10131', '10132', '10133',
#        '10138', '10149', '10150', '10151', '10152', '10153', '10154',
#        '10155', '10156', '10157', '10158', '10159', '10160', '10162',
#        '10163', '10164', '10165', '10166', '10167', '10168', '10169',
#        '10170', '10171', '10172', '10173', '10174', '10175', '10176',
#        '10177', '10178', '10179', '10185', '10199', '10213', '10242',
#        '10249', '10256', '10259', '10260', '10261', '10265', '10268',
#        '10269', '10270', '10271', '10272', '10273', '10274', '10275',
#        '10276', '10277', '10278', '10279', '10280', '10281', '10282',
#        '10285', '10286', '10463'], dtype=object)

# %%
ccod_ny_metro = ccd[ccd["zip"].isin(ny["zip"])]
ccod_ny_metro.count()
# Out:
# NCESSCH         354
# FIPST           354
# LEAID           354
# school_id       354
# STID07          354
#                ...
# Unnamed: 224      0
# Unnamed: 225      0
# Unnamed: 226      0
# Unnamed: 227      0
# Unnamed: 228      0
# Length: 229, dtype: int64

# %%
ccod_ny_metro = ccod_ny_metro[["school_id", "ASIAN07", "BLACK07", "HISP07", "WHITE07"]]
ccod_ny_metro.rename(columns={"ASIAN07": "asian_n", "BLACK07": "black_n", "HISP07": "hispanic_n", "WHITE07":"white_n"}, inplace=True)
ccod_ny_metro.to_csv("_data/ccod-2007-ny_metro.csv", index=False)
