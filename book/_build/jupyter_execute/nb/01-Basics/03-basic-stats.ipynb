# %% [markdown]
# Basic Statistics
# ================
#
# This Notebook shows us how to use the `pandas` to find
# basic quantitative descriptions of our data
#
# Topics in this Notebook:
#
# - dropping columns
# - minimum and maximum ranges
# - averages
# - counts
# - sorting data
# - correlations with `corr()`
# - `describe()`

# %%
# import schools from the nycschool package
from nycschools import schools

# load the demographic data into a `DataFrame` called df
df = schools.load_school_demographics()

# let's just use one year of data
df = df[df.ay == 2020]

# use a subset of columns for this notebook
cols = [
    'dbn',
    'district',
    'boro',
    'school_name',
    'total_enrollment',
    'asian_pct',
    'black_pct',
    'hispanic_pct',
    'white_pct',
    'swd_pct',
    'ell_pct',
    'poverty_pct'
]
df = df[cols]


df.head()
# Out:
#        dbn  district       boro                     school_name  \
# 4   01M015         1  Manhattan       P.S. 015 Roberto Clemente
# 9   01M019         1  Manhattan             P.S. 019 Asher Levy
# 14  01M020         1  Manhattan            P.S. 020 Anna Silver
# 19  01M034         1  Manhattan  P.S. 034 Franklin D. Roosevelt
# 24  01M063         1  Manhattan       The STAR Academy - P.S.63
#
#     total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct  swd_pct  \
# 4                193      0.135      0.275         0.528      0.057    0.223
# 9                212      0.061      0.193         0.613      0.080    0.392
# 14               412      0.248      0.133         0.522      0.073    0.218
# 19               273      0.026      0.381         0.557      0.029    0.392
# 24               208      0.029      0.192         0.635      0.091    0.279
#
#     ell_pct  poverty_pct
# 4     0.109        0.819
# 9     0.042        0.712
# 14    0.119        0.709
# 19    0.062        0.960
# 24    0.014        0.769

# %%
# sort the data and show just the 10 largest schools
# sort in descending order (biggest --> smallest)
data = df.sort_values(by="total_enrollment", ascending=False)

# show the first 10 rows
data[:10]
# Out:
#          dbn  district           boro                      school_name  \
# 3723  13K430        13       Brooklyn   Brooklyn Technical High School
# 5310  20K490        20       Brooklyn        Fort Hamilton High School
# 6686  26Q430        26         Queens        Francis Lewis High School
# 5802  22K405        22       Brooklyn              Midwood High School
# 5807  22K425        22       Brooklyn        James Madison High School
# 7279  28Q440        28         Queens         Forest Hills High School
# 8199  31R455        31  Staten Island          Tottenville High School
# 5557  21K525        21       Brooklyn     Edward R. Murrow High School
# 5300  20K445        20       Brooklyn          New Utrecht High School
# 6681  26Q415        26         Queens  Benjamin N. Cardozo High School
#
#       total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct  \
# 3723              5921      0.599      0.056         0.066      0.237
# 5310              4678      0.290      0.025         0.317      0.347
# 6686              4424      0.577      0.047         0.210      0.150
# 5802              4109      0.354      0.255         0.133      0.225
# 5807              3851      0.209      0.128         0.175      0.472
# 7279              3775      0.247      0.065         0.381      0.272
# 8199              3726      0.072      0.014         0.132      0.761
# 5557              3691      0.274      0.176         0.193      0.308
# 5300              3572      0.391      0.030         0.336      0.234
# 6681              3405      0.423      0.214         0.223      0.120
#
#       swd_pct  ell_pct  poverty_pct
# 3723    0.016    0.001        0.590
# 5310    0.153    0.162        0.706
# 6686    0.150    0.115        0.690
# 5802    0.138    0.036        0.723
# 5807    0.154    0.121        0.758
# 7279    0.164    0.093        0.702
# 8199    0.227    0.023        0.416
# 5557    0.178    0.125        0.670
# 5300    0.165    0.218        0.796
# 6681    0.145    0.051        0.668

# %%
# get just the total_enrollment column, called a Series in pandas
enrollment = df["total_enrollment"]
print("The largest school:", enrollment.max())
print("The smallest school:", enrollment.min())

print("Avg (mean) school size:", enrollment.mean())
print("Avg (median) school size:", enrollment.median())
print("Avg (mode, can return multiple values) school size:", list(enrollment.mode()))
# Out:
# The largest school: 5921
# The smallest school: 7
# Avg (mean) school size: 560.79296875
# Avg (median) school size: 460.5
# Avg (mode, can return multiple values) school size: [479, 714]

# %%
# the built in describe() function calculates several descriptive statististics for each column
# in the data frame and returns them as a new dataframe
df.describe()
# Out:
#          district  total_enrollment    asian_pct    black_pct  hispanic_pct  \
# count  2048.00000       2048.000000  2048.000000  2048.000000   2048.000000
# mean     27.62207        560.792969     0.117710     0.302644      0.431721
# std      26.68098        461.014510     0.166804     0.256375      0.246118
# min       1.00000          7.000000     0.000000     0.000000      0.015000
# 25%      10.00000        304.000000     0.015000     0.081474      0.206000
# 50%      19.00000        460.500000     0.046000     0.245000      0.405000
# 75%      30.00000        663.250000     0.148000     0.472250      0.631250
# max      84.00000       5921.000000     0.926000     0.935000      1.000000
#
#          white_pct      swd_pct      ell_pct  poverty_pct
# count  2048.000000  2048.000000  2048.000000  2048.000000
# mean      0.118602     0.237641     0.141212     0.766560
# std       0.168041     0.160780     0.143127     0.194297
# min       0.000000     0.000000     0.000000     0.050000
# 25%       0.016000     0.163000     0.049000     0.711000
# 50%       0.036000     0.208000     0.100000     0.827000
# 75%       0.145250     0.261000     0.187250     0.903000
# max       0.945000     1.000000     1.000000     0.960000

# %%
# we can also call describe aon a single series:
df.swd_pct.describe()
# Out:
# count    2048.000000
# mean        0.237641
# std         0.160780
# min         0.000000
# 25%         0.163000
# 50%         0.208000
# 75%         0.261000
# max         1.000000
# Name: swd_pct, dtype: float64

# %%
# we can also call the corr() method to show correclations between columns
# we will take out "district" from this data because the district number
# is categorical -- not the measure of a value

# correlations close to 1 or negative one show high correlations
# closer to zero items are not closely correlated
data = df.drop(columns=["district"])
data.corr()
# Out:
# /tmp/ipykernel_18804/792112253.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   total_enrollment  asian_pct  black_pct  hispanic_pct  \
# total_enrollment          1.000000   0.350881  -0.242553     -0.111551
# asian_pct                 0.350881   1.000000  -0.452366     -0.370264
# black_pct                -0.242553  -0.452366   1.000000     -0.416505
# hispanic_pct             -0.111551  -0.370264  -0.416505      1.000000
# white_pct                 0.179056   0.210809  -0.450801     -0.396739
# swd_pct                  -0.175962  -0.210489   0.138008      0.070421
# ell_pct                  -0.018582   0.138261  -0.362794      0.441878
# poverty_pct              -0.155614  -0.287675   0.299685      0.490632
#
#                   white_pct   swd_pct   ell_pct  poverty_pct
# total_enrollment   0.179056 -0.175962 -0.018582    -0.155614
# asian_pct          0.210809 -0.210489  0.138261    -0.287675
# black_pct         -0.450801  0.138008 -0.362794     0.299685
# hispanic_pct      -0.396739  0.070421  0.441878     0.490632
# white_pct          1.000000 -0.083534 -0.177996    -0.795595
# swd_pct           -0.083534  1.000000  0.000117     0.233832
# ell_pct           -0.177996  0.000117  1.000000     0.359285
# poverty_pct       -0.795595  0.233832  0.359285     1.000000

# %%
# last, we can use styles to make the correlation table easier to read
# note: you need to run this cell to see the colors -- it's get saved without the styled output
corr = data.corr()
# a coolwarm color map will show values in a gradient where -1 is the deepest blue and 1 is deepest red
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_18804/143913075.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <style type="text/css">
# #T_ff855_row0_col0, #T_ff855_row1_col1, #T_ff855_row2_col2, #T_ff855_row3_col3, #T_ff855_row4_col4, #T_ff855_row5_col5, #T_ff855_row6_col6, #T_ff855_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ff855_row0_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ff855_row0_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ff855_row0_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ff855_row0_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ff855_row0_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ff855_row0_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ff855_row0_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ff855_row1_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_ff855_row1_col2, #T_ff855_row1_col5, #T_ff855_row2_col0, #T_ff855_row2_col1, #T_ff855_row2_col3, #T_ff855_row2_col6, #T_ff855_row4_col2, #T_ff855_row4_col7, #T_ff855_row7_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ff855_row1_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ff855_row1_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ff855_row1_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ff855_row1_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ff855_row2_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ff855_row2_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ff855_row2_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ff855_row3_col0, #T_ff855_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ff855_row3_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ff855_row3_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ff855_row3_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ff855_row3_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ff855_row3_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_ff855_row3_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ff855_row4_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ff855_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ff855_row4_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ff855_row4_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ff855_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ff855_row5_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ff855_row5_col2, #T_ff855_row6_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ff855_row5_col3, #T_ff855_row6_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ff855_row5_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ff855_row5_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ff855_row5_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ff855_row6_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ff855_row6_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ff855_row6_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_ff855_row6_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ff855_row6_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_ff855_row7_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ff855_row7_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ff855_row7_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ff855_row7_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ff855_row7_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ff855_row7_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# </style>
# <table id="T_ff855">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff855_level0_col0" class="col_heading level0 col0" >total_enrollment</th>
#       <th id="T_ff855_level0_col1" class="col_heading level0 col1" >asian_pct</th>
#       <th id="T_ff855_level0_col2" class="col_heading level0 col2" >black_pct</th>
#       <th id="T_ff855_level0_col3" class="col_heading level0 col3" >hispanic_pct</th>
#       <th id="T_ff855_level0_col4" class="col_heading level0 col4" >white_pct</th>
#       <th id="T_ff855_level0_col5" class="col_heading level0 col5" >swd_pct</th>
#       <th id="T_ff855_level0_col6" class="col_heading level0 col6" >ell_pct</th>
#       <th id="T_ff855_level0_col7" class="col_heading level0 col7" >poverty_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff855_level0_row0" class="row_heading level0 row0" >total_enrollment</th>
#       <td id="T_ff855_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ff855_row0_col1" class="data row0 col1" >0.350881</td>
#       <td id="T_ff855_row0_col2" class="data row0 col2" >-0.242553</td>
#       <td id="T_ff855_row0_col3" class="data row0 col3" >-0.111551</td>
#       <td id="T_ff855_row0_col4" class="data row0 col4" >0.179056</td>
#       <td id="T_ff855_row0_col5" class="data row0 col5" >-0.175962</td>
#       <td id="T_ff855_row0_col6" class="data row0 col6" >-0.018582</td>
#       <td id="T_ff855_row0_col7" class="data row0 col7" >-0.155614</td>
#     </tr>
#     <tr>
#       <th id="T_ff855_level0_row1" class="row_heading level0 row1" >asian_pct</th>
#       <td id="T_ff855_row1_col0" class="data row1 col0" >0.350881</td>
#       <td id="T_ff855_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ff855_row1_col2" class="data row1 col2" >-0.452366</td>
#       <td id="T_ff855_row1_col3" class="data row1 col3" >-0.370264</td>
#       <td id="T_ff855_row1_col4" class="data row1 col4" >0.210809</td>
#       <td id="T_ff855_row1_col5" class="data row1 col5" >-0.210489</td>
#       <td id="T_ff855_row1_col6" class="data row1 col6" >0.138261</td>
#       <td id="T_ff855_row1_col7" class="data row1 col7" >-0.287675</td>
#     </tr>
#     <tr>
#       <th id="T_ff855_level0_row2" class="row_heading level0 row2" >black_pct</th>
#       <td id="T_ff855_row2_col0" class="data row2 col0" >-0.242553</td>
#       <td id="T_ff855_row2_col1" class="data row2 col1" >-0.452366</td>
#       <td id="T_ff855_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ff855_row2_col3" class="data row2 col3" >-0.416505</td>
#       <td id="T_ff855_row2_col4" class="data row2 col4" >-0.450801</td>
#       <td id="T_ff855_row2_col5" class="data row2 col5" >0.138008</td>
#       <td id="T_ff855_row2_col6" class="data row2 col6" >-0.362794</td>
#       <td id="T_ff855_row2_col7" class="data row2 col7" >0.299685</td>
#     </tr>
#     <tr>
#       <th id="T_ff855_level0_row3" class="row_heading level0 row3" >hispanic_pct</th>
#       <td id="T_ff855_row3_col0" class="data row3 col0" >-0.111551</td>
#       <td id="T_ff855_row3_col1" class="data row3 col1" >-0.370264</td>
#       <td id="T_ff855_row3_col2" class="data row3 col2" >-0.416505</td>
#       <td id="T_ff855_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ff855_row3_col4" class="data row3 col4" >-0.396739</td>
#       <td id="T_ff855_row3_col5" class="data row3 col5" >0.070421</td>
#       <td id="T_ff855_row3_col6" class="data row3 col6" >0.441878</td>
#       <td id="T_ff855_row3_col7" class="data row3 col7" >0.490632</td>
#     </tr>
#     <tr>
#       <th id="T_ff855_level0_row4" class="row_heading level0 row4" >white_pct</th>
#       <td id="T_ff855_row4_col0" class="data row4 col0" >0.179056</td>
#       <td id="T_ff855_row4_col1" class="data row4 col1" >0.210809</td>
#       <td id="T_ff855_row4_col2" class="data row4 col2" >-0.450801</td>
#       <td id="T_ff855_row4_col3" class="data row4 col3" >-0.396739</td>
#       <td id="T_ff855_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ff855_row4_col5" class="data row4 col5" >-0.083534</td>
#       <td id="T_ff855_row4_col6" class="data row4 col6" >-0.177996</td>
#       <td id="T_ff855_row4_col7" class="data row4 col7" >-0.795595</td>
#     </tr>
#     <tr>
#       <th id="T_ff855_level0_row5" class="row_heading level0 row5" >swd_pct</th>
#       <td id="T_ff855_row5_col0" class="data row5 col0" >-0.175962</td>
#       <td id="T_ff855_row5_col1" class="data row5 col1"
