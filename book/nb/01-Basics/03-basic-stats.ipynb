# %% [markdown]
# New York City School Data Basics
# =============================
# 03 Basic Statistics <small>[[◀ 02 Querying Data](02-querying-data.ipynb)] [[04 Calculating New Columns ▶](04-calculating-columns.ipynb)]</small>
# ---------------------------------------------------------------------
#
# This Notebook shows us how to use the `pandas` library to find
# basic quantitative descriptions of our data
#
# Topics in this Notebook:
# <br><br>
# - selecting/dropping columns
# - sorting data using [`sort_values()`](https://www.w3schools.com/python/pandas/ref_df_sort_values.asp) method
# - ['slicing'](https://datacarpentry.org/python-ecology-lesson/03-index-slice-subset/#extracting-range-based-subsets-slicing) DataFrames with `[]` operator
# <br><br>
# - calculating various statistics of sets of data using [methods](https://www.w3schools.com/python/pandas/pandas_ref_dataframe.asp) of DataFrames [`min()`, `max()`, `mean()`, `median()`, `mode()`...]
# - statistical summaries with [`describe()`](https://www.w3schools.com/python/pandas/ref_df_describe.asp)
# - correlation matrices with [`corr()`](https://www.w3schools.com/python/pandas/ref_df_corr.asp)

# %%
# import schools from the nycschool package
from nycschools import schools

# load the demographic data into a `DataFrame` called df
df = schools.load_school_demographics()

# let's just use one year of data
df = df[df.ay == 2020]

# use a subset of columns for this notebook
cols = [
    'dbn',
    'district',
    'boro',
    'school_name',
    'total_enrollment',
    'asian_pct',
    'black_pct',
    'hispanic_pct',
    'white_pct',
    'swd_pct',
    'ell_pct',
    'poverty_pct'
]
df = df[cols]


df.head()
# Out:
#        dbn  district       boro                     school_name
# 4   01M015         1  Manhattan       P.S. 015 Roberto Clemente  \
# 9   01M019         1  Manhattan             P.S. 019 Asher Levy
# 14  01M020         1  Manhattan            P.S. 020 Anna Silver
# 19  01M034         1  Manhattan  P.S. 034 Franklin D. Roosevelt
# 24  01M063         1  Manhattan       The STAR Academy - P.S.63
#
#     total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct  swd_pct
# 4                193      0.135      0.275         0.528      0.057    0.223  \
# 9                212      0.061      0.193         0.613      0.080    0.392
# 14               412      0.248      0.133         0.522      0.073    0.218
# 19               273      0.026      0.381         0.557      0.029    0.392
# 24               208      0.029      0.192         0.635      0.091    0.279
#
#     ell_pct  poverty_pct
# 4     0.109        0.819
# 9     0.042        0.712
# 14    0.119        0.709
# 19    0.062        0.960
# 24    0.014        0.769

# %%
# sort enrollments in descending order (greatest to least) by using the 'by' and 'ascending' parameters

data = df.sort_values(by="total_enrollment", ascending=False)
data

# Comment out the two lines of code above and uncomment 
# the ones below to sort enrollments in ascending order (least to greatest)
# Take note of the change to the 'ascending' parameter

# data = df.sort_values(by="total_enrollment", ascending=True)
# data
# Out:
#          dbn  district       boro                            school_name
# 3723  13K430        13   Brooklyn         Brooklyn Technical High School  \
# 5310  20K490        20   Brooklyn              Fort Hamilton High School
# 6686  26Q430        26     Queens              Francis Lewis High School
# 5802  22K405        22   Brooklyn                    Midwood High School
# 5807  22K425        22   Brooklyn              James Madison High School
# ...      ...       ...        ...                                    ...
# 9324  84M337        84  Manhattan  NYC Autism Charter School East Harlem
# 9906  84X587        84      Bronx        NYC Autism Charter School Bronx
# 9965  84X633        84      Bronx     Wildflower New York Charter School
# 8712  79M331        79  Manhattan        The Judith S. Kaye School - D79
# 3573  12X626        12      Bronx               District 12 Pre-K Center
#
#       total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct
# 3723              5921   0.599000   0.056000      0.066000   0.237000  \
# 5310              4678   0.290000   0.025000      0.317000   0.347000
# 6686              4424   0.577000   0.047000      0.210000   0.150000
# 5802              4109   0.354000   0.255000      0.133000   0.225000
# 5807              3851   0.209000   0.128000      0.175000   0.472000
# ...                ...        ...        ...           ...        ...
# 9324                40   0.075000   0.200000      0.475000   0.200000
# 9906                28   0.071429   0.392857      0.500000   0.035714
# 9965                19   0.000000   0.578947      0.421053   0.000000
# 8712                14   0.071000   0.429000      0.500000   0.000000
# 3573                 7   0.000000   0.286000      0.714000   0.000000
#
#        swd_pct  ell_pct  poverty_pct
# 3723  0.016000    0.001        0.590
# 5310  0.153000    0.162        0.706
# 6686  0.150000    0.115        0.690
# 5802  0.138000    0.036        0.723
# 5807  0.154000    0.121        0.758
# ...        ...      ...          ...
# 9324  1.000000    0.025        0.950
# 9906  1.000000    0.036        0.893
# 9965  0.263158    0.053        0.842
# 8712  0.429000    0.000        0.857
# 3573  0.000000    0.000        0.714
#
# [2048 rows x 12 columns]

# %%
# show the first 3 rows

data[:3]
# Out:
#          dbn  district      boro                     school_name
# 3723  13K430        13  Brooklyn  Brooklyn Technical High School  \
# 5310  20K490        20  Brooklyn       Fort Hamilton High School
# 6686  26Q430        26    Queens       Francis Lewis High School
#
#       total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct
# 3723              5921      0.599      0.056         0.066      0.237  \
# 5310              4678      0.290      0.025         0.317      0.347
# 6686              4424      0.577      0.047         0.210      0.150
#
#       swd_pct  ell_pct  poverty_pct
# 3723    0.016    0.001        0.590
# 5310    0.153    0.162        0.706
# 6686    0.150    0.115        0.690

# %%
# get just the total_enrollment column, called a Series in pandas
enrollment = df["total_enrollment"]

# locate the maxmimum enrollment
print("The largest school:", enrollment.max())

# locate the minimum enrollment
print("The smallest school:", enrollment.min())

# calculate the average enrollment
print("Average school size:", enrollment.mean())

# calculate the median enrollment
print("Median school size:", enrollment.median())

# calculate the mode of enrollments
print("Mode (can return multiple values) of school sizes:", list(enrollment.mode()))
# Out:
# The largest school: 5921
# The smallest school: 7
# Average school size: 560.79296875
# Median school size: 460.5
# Mode (can return multiple values) of school sizes: [479, 714]

# %%
# the built in describe() function calculates several descriptive statistics for each column
# in the data frame and returns them as a new dataframe
df.describe()
# Out:
#          district  total_enrollment    asian_pct    black_pct  hispanic_pct
# count  2048.00000       2048.000000  2048.000000  2048.000000   2048.000000  \
# mean     27.62207        560.792969     0.117710     0.302644      0.431721
# std      26.68098        461.014510     0.166804     0.256375      0.246118
# min       1.00000          7.000000     0.000000     0.000000      0.015000
# 25%      10.00000        304.000000     0.015000     0.081474      0.206000
# 50%      19.00000        460.500000     0.046000     0.245000      0.405000
# 75%      30.00000        663.250000     0.148000     0.472250      0.631250
# max      84.00000       5921.000000     0.926000     0.935000      1.000000
#
#          white_pct      swd_pct      ell_pct  poverty_pct
# count  2048.000000  2048.000000  2048.000000  2048.000000
# mean      0.118602     0.237641     0.141212     0.766560
# std       0.168041     0.160780     0.143127     0.194297
# min       0.000000     0.000000     0.000000     0.050000
# 25%       0.016000     0.163000     0.049000     0.711000
# 50%       0.036000     0.208000     0.100000     0.827000
# 75%       0.145250     0.261000     0.187250     0.903000
# max       0.945000     1.000000     1.000000     0.960000

# %%
# we can also call describe on a single series:
df.swd_pct.describe()
# Out:
# count    2048.000000
# mean        0.237641
# std         0.160780
# min         0.000000
# 25%         0.163000
# 50%         0.208000
# 75%         0.261000
# max         1.000000
# Name: swd_pct, dtype: float64

# %%
# just checking in on what our DateFrame 'df' looks like
df
# Out:
#           dbn  district       boro                               school_name
# 4      01M015         1  Manhattan                 P.S. 015 Roberto Clemente  \
# 9      01M019         1  Manhattan                       P.S. 019 Asher Levy
# 14     01M020         1  Manhattan                      P.S. 020 Anna Silver
# 19     01M034         1  Manhattan            P.S. 034 Franklin D. Roosevelt
# 24     01M063         1  Manhattan                 The STAR Academy - P.S.63
# ...       ...       ...        ...                                       ...
# 9980   84X705        84      Bronx        Family Life Academy Charter School
# 9985   84X706        84      Bronx             Harriet Tubman Charter School
# 9990   84X717        84      Bronx                      Icahn Charter School
# 9995   84X718        84      Bronx  Bronx Charter School for Better Learning
# 10000  84X730        84      Bronx         Bronx Charter School for the Arts
#
#        total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct
# 4                   193   0.135000   0.275000      0.528000   0.057000  \
# 9                   212   0.061000   0.193000      0.613000   0.080000
# 14                  412   0.248000   0.133000      0.522000   0.073000
# 19                  273   0.026000   0.381000      0.557000   0.029000
# 24                  208   0.029000   0.192000      0.635000   0.091000
# ...                 ...        ...        ...           ...        ...
# 9980                416   0.007212   0.211538      0.776442   0.000000
# 9985                647   0.000000   0.616692      0.358578   0.006182
# 9990                328   0.012195   0.500000      0.478659   0.000000
# 9995                570   0.008772   0.845614      0.100000   0.014035
# 10000               626   0.004792   0.268371      0.704473   0.006390
#
#         swd_pct  ell_pct  poverty_pct
# 4      0.223000    0.109        0.819
# 9      0.392000    0.042        0.712
# 14     0.218000    0.119        0.709
# 19     0.392000    0.062        0.960
# 24     0.279000    0.014        0.769
# ...         ...      ...          ...
# 9980   0.100962    0.197        0.960
# 9985   0.097372    0.110        0.832
# 9990   0.070122    0.076        0.878
# 9995   0.108772    0.012        0.819
# 10000  0.244409    0.125        0.864
#
# [2048 rows x 12 columns]

# %%
# we can also call the corr() method to show correlations between columns
# we will take out "district", "dbn", "school_name", and "boro" from this data because these are categorical -- not the measure of a value

# correlations close to -1 or 1 represent strong correlations
# correlations closer to 0 represent weak correlations
data = df.drop(columns=["district", "dbn", "school_name", "boro"])
data.corr()
# Out:
#                   total_enrollment  asian_pct  black_pct  hispanic_pct
# total_enrollment          1.000000   0.350881  -0.242553     -0.111551  \
# asian_pct                 0.350881   1.000000  -0.452366     -0.370264
# black_pct                -0.242553  -0.452366   1.000000     -0.416505
# hispanic_pct             -0.111551  -0.370264  -0.416505      1.000000
# white_pct                 0.179056   0.210809  -0.450801     -0.396739
# swd_pct                  -0.175962  -0.210489   0.138008      0.070421
# ell_pct                  -0.018582   0.138261  -0.362794      0.441878
# poverty_pct              -0.155614  -0.287675   0.299685      0.490632
#
#                   white_pct   swd_pct   ell_pct  poverty_pct
# total_enrollment   0.179056 -0.175962 -0.018582    -0.155614
# asian_pct          0.210809 -0.210489  0.138261    -0.287675
# black_pct         -0.450801  0.138008 -0.362794     0.299685
# hispanic_pct      -0.396739  0.070421  0.441878     0.490632
# white_pct          1.000000 -0.083534 -0.177996    -0.795595
# swd_pct           -0.083534  1.000000  0.000117     0.233832
# ell_pct           -0.177996  0.000117  1.000000     0.359285
# poverty_pct       -0.795595  0.233832  0.359285     1.000000

# %%
# last, we can use styles to make the correlation table easier to read
# note: you need to run this cell to see the colors -- it gets saved without the styled output
corr = data.corr()

# a coolwarm color map will show values in a gradient where -1 is the deepest blue and 1 is deepest red
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ee5c6_row0_col0, #T_ee5c6_row1_col1, #T_ee5c6_row2_col2, #T_ee5c6_row3_col3, #T_ee5c6_row4_col4, #T_ee5c6_row5_col5, #T_ee5c6_row6_col6, #T_ee5c6_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ee5c6_row0_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ee5c6_row0_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ee5c6_row0_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ee5c6_row0_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ee5c6_row0_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ee5c6_row0_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ee5c6_row0_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ee5c6_row1_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_ee5c6_row1_col2, #T_ee5c6_row1_col5, #T_ee5c6_row2_col0, #T_ee5c6_row2_col1, #T_ee5c6_row2_col3, #T_ee5c6_row2_col6, #T_ee5c6_row4_col2, #T_ee5c6_row4_col7, #T_ee5c6_row7_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ee5c6_row1_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ee5c6_row1_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ee5c6_row1_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ee5c6_row1_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ee5c6_row2_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ee5c6_row2_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ee5c6_row2_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ee5c6_row3_col0, #T_ee5c6_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ee5c6_row3_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ee5c6_row3_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ee5c6_row3_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ee5c6_row3_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ee5c6_row3_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_ee5c6_row3_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ee5c6_row4_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ee5c6_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ee5c6_row4_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ee5c6_row4_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ee5c6_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ee5c6_row5_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ee5c6_row5_col2, #T_ee5c6_row6_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ee5c6_row5_col3, #T_ee5c6_row6_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ee5c6_row5_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ee5c6_row5_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ee5c6_row5_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ee5c6_row6_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ee5c6_row6_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ee5c6_row6_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_ee5c6_row6_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ee5c6_row6_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_ee5c6_row7_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ee5c6_row7_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ee5c6_row7_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ee5c6_row7_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ee5c6_row7_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ee5c6_row7_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# </style>
# <table id="T_ee5c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee5c6_level0_col0" class="col_heading level0 col0" >total_enrollment</th>
#       <th id="T_ee5c6_level0_col1" class="col_heading level0 col1" >asian_pct</th>
#       <th id="T_ee5c6_level0_col2" class="col_heading level0 col2" >black_pct</th>
#       <th id="T_ee5c6_level0_col3" class="col_heading level0 col3" >hispanic_pct</th>
#       <th id="T_ee5c6_level0_col4" class="col_heading level0 col4" >white_pct</th>
#       <th id="T_ee5c6_level0_col5" class="col_heading level0 col5" >swd_pct</th>
#       <th id="T_ee5c6_level0_col6" class="col_heading level0 col6" >ell_pct</th>
#       <th id="T_ee5c6_level0_col7" class="col_heading level0 col7" >poverty_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee5c6_level0_row0" class="row_heading level0 row0" >total_enrollment</th>
#       <td id="T_ee5c6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ee5c6_row0_col1" class="data row0 col1" >0.350881</td>
#       <td id="T_ee5c6_row0_col2" class="data row0 col2" >-0.242553</td>
#       <td id="T_ee5c6_row0_col3" class="data row0 col3" >-0.111551</td>
#       <td id="T_ee5c6_row0_col4" class="data row0 col4" >0.179056</td>
#       <td id="T_ee5c6_row0_col5" class="data row0 col5" >-0.175962</td>
#       <td id="T_ee5c6_row0_col6" class="data row0 col6" >-0.018582</td>
#       <td id="T_ee5c6_row0_col7" class="data row0 col7" >-0.155614</td>
#     </tr>
#     <tr>
#       <th id="T_ee5c6_level0_row1" class="row_heading level0 row1" >asian_pct</th>
#       <td id="T_ee5c6_row1_col0" class="data row1 col0" >0.350881</td>
#       <td id="T_ee5c6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ee5c6_row1_col2" class="data row1 col2" >-0.452366</td>
#       <td id="T_ee5c6_row1_col3" class="data row1 col3" >-0.370264</td>
#       <td id="T_ee5c6_row1_col4" class="data row1 col4" >0.210809</td>
#       <td id="T_ee5c6_row1_col5" class="data row1 col5" >-0.210489</td>
#       <td id="T_ee5c6_row1_col6" class="data row1 col6" >0.138261</td>
#       <td id="T_ee5c6_row1_col7" class="data row1 col7" >-0.287675</td>
#     </tr>
#     <tr>
#       <th id="T_ee5c6_level0_row2" class="row_heading level0 row2" >black_pct</th>
#       <td id="T_ee5c6_row2_col0" class="data row2 col0" >-0.242553</td>
#       <td id="T_ee5c6_row2_col1" class="data row2 col1" >-0.452366</td>
#       <td id="T_ee5c6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ee5c6_row2_col3" class="data row2 col3" >-0.416505</td>
#       <td id="T_ee5c6_row2_col4" class="data row2 col4" >-0.450801</td>
#       <td id="T_ee5c6_row2_col5" class="data row2 col5" >0.138008</td>
#       <td id="T_ee5c6_row2_col6" class="data row2 col6" >-0.362794</td>
#       <td id="T_ee5c6_row2_col7" class="data row2 col7" >0.299685</td>
#     </tr>
#     <tr>
#       <th id="T_ee5c6_level0_row3" class="row_heading level0 row3" >hispanic_pct</th>
#       <td id="T_ee5c6_row3_col0" class="data row3 col0" >-0.111551</td>
#       <td id="T_ee5c6_row3_col1" class="data row3 col1" >-0.370264</td>
#       <td id="T_ee5c6_row3_col2" class="data row3 col2" >-0.416505</td>
#       <td id="T_ee5c6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ee5c6_row3_col4" class="data row3 col4" >-0.396739</td>
#       <td id="T_ee5c6_row3_col5" class="data row3 col5" >0.070421</td>
#       <td id="T_ee5c6_row3_col6" class="data row3 col6" >0.441878</td>
#       <td id="T_ee5c6_row3_col7" class="data row3 col7" >0.490632</td>
#     </tr>
#     <tr>
#       <th id="T_ee5c6_level0_row4" class="row_heading level0 row4" >white_pct</th>
#       <td id="T_ee5c6_row4_col0" class="data row4 col0" >0.179056</td>
#       <td id="T_ee5c6_row4_col1" class="data row4 col1" >0.210809</td>
#       <td id="T_ee5c6_row4_col2" class="data row4 col2" >-0.450801</td>
#       <td id="T_ee5c6_row4_col3" class="data row4 col3" >-0.396739</td>
#       <td id="T_ee5c6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ee5c6_row4_col5" class="data row4 col5" >-0.083534</td>
#       <td id="T_ee5c6_row4_col6" class="data row4 col6" >-0.177996</td>
#       <td id="T_ee5c6_row4_col7" class="data row4 col7" >-0.795595</td>
#     </tr>
#     <tr>
#       <th id="T_ee5c6_level0_row5" class="row_heading level0 row5" >swd_pct</th>
#       <td id="T_ee5c6_row5_col0" class="data row5 col0" >-0.175962</td>
#       <td id="T_ee5c6_row5_col1" class="data row5 col1"
