# %% [markdown]
# Basic Statistics
# ================
#
# This Notebook shows us how to use the `pandas` to find
# basic quantitative descriptions of our data
#
# Topics in this Notebook:
#
# - dropping columns
# - minimum and maximum ranges
# - averages
# - counts
# - sorting data
# - correlations with `corr()`
# - `describe()`

# %%
# import schools from the nycschool package
from nycschools import schools

# load the demographic data into a `DataFrame` called df
df = schools.load_school_demographics()

# let's just use one year of data
df = df[df.ay == 2020]

# use a subset of columns for this notebook
cols = [
    'dbn',
    'district',
    'boro',
    'school_name',
    'total_enrollment',
    'asian_pct',
    'black_pct',
    'hispanic_pct',
    'white_pct',
    'swd_pct',
    'ell_pct',
    'poverty_pct'
]
df = df[cols]


df.head()
# Out:
#          dbn  district       boro                     school_name  \
# 1790  01M015         1  Manhattan       P.S. 015 Roberto Clemente
# 1795  01M020         1  Manhattan            P.S. 020 Anna Silver
# 1800  01M034         1  Manhattan  P.S. 034 Franklin D. Roosevelt
# 1805  01M063         1  Manhattan       The STAR Academy - P.S.63
# 1810  01M064         1  Manhattan           P.S. 064 Robert Simon
#
#       total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct  \
# 1790               193   0.134715   0.274611      0.528497   0.056995
# 1795               412   0.247573   0.133495      0.521845   0.072816
# 1800               273   0.025641   0.380952      0.556777   0.029304
# 1805               208   0.028846   0.192308      0.634615   0.091346
# 1810               220   0.031818   0.181818      0.727273   0.040909
#
#        swd_pct   ell_pct  poverty_pct
# 1790  0.227979  0.108808     0.834197
# 1795  0.223301  0.118932     0.720874
# 1800  0.395604  0.062271     0.960000
# 1805  0.283654  0.014423     0.778846
# 1810  0.277273  0.018182     0.918182

# %%
# sort the data and show just the 10 largest schools
# sort in descending order (biggest --> smallest)
data = df.sort_values(by="total_enrollment", ascending=False)

# show the first 10 rows
data[:10]
# Out:
#          dbn  district           boro                      school_name  \
# 5154  13K430        13       Brooklyn   Brooklyn Technical High School
# 6617  20K490        20       Brooklyn        Fort Hamilton High School
# 7887  26Q430        26         Queens        Francis Lewis High School
# 7038  22K405        22       Brooklyn              Midwood High School
# 7043  22K425        22       Brooklyn        James Madison High School
# 8442  28Q440        28         Queens         Forest Hills High School
# 9309  31R455        31  Staten Island          Tottenville High School
# 6838  21K525        21       Brooklyn     Edward R. Murrow High School
# 6607  20K445        20       Brooklyn          New Utrecht High School
# 7882  26Q415        26         Queens  Benjamin N. Cardozo High School
#
#       total_enrollment  asian_pct  black_pct  hispanic_pct  white_pct  \
# 5154              5921   0.598716   0.056409      0.066036   0.236615
# 6617              4678   0.289654   0.024583      0.316802   0.346729
# 7887              4424   0.576854   0.047242      0.210443   0.150316
# 7038              4109   0.353857   0.255293      0.133366   0.224629
# 7043              3851   0.209296   0.128278      0.174500   0.471826
# 8442              3775   0.246623   0.065166      0.380927   0.271788
# 9309              3726   0.072195   0.014224      0.132045   0.760601
# 6838              3691   0.274180   0.176104      0.192631   0.308318
# 6607              3572   0.390817   0.030235      0.335946   0.233763
# 7882              3405   0.422908   0.213803      0.222907   0.120117
#
#        swd_pct   ell_pct  poverty_pct
# 5154  0.015200  0.000844     0.595676
# 6617  0.150492  0.162035     0.712911
# 7887  0.148960  0.114602     0.695072
# 7038  0.138720  0.035775     0.729131
# 7043  0.153726  0.120748     0.762399
# 8442  0.164503  0.094040     0.711258
# 9309  0.224101  0.023349     0.423510
# 6838  0.178542  0.124898     0.678136
# 6607  0.164614  0.217805     0.807391
# 7882  0.145668  0.050514     0.671953

# %%
# get just the total_enrollment column, called a Series in pandas
enrollment = df["total_enrollment"]
print("The largest school:", enrollment.max())
print("The smallest school:", enrollment.min())

print("Avg (mean) school size:", enrollment.mean())
print("Avg (median) school size:", enrollment.median())
print("Avg (mode, can return multiple values) school size:", list(enrollment.mode()))
# Out:
# The largest school: 5921
# The smallest school: 7
# Avg (mean) school size: 559.7328
# Avg (median) school size: 456.0
# Avg (mode, can return multiple values) school size: [373]

# %%
# the built in describe() function calculates several descriptive statististics for each column
# in the data frame and returns them as a new dataframe
df.describe()
# Out:
#           district  total_enrollment    asian_pct    black_pct  hispanic_pct  \
# count  1875.000000        1875.00000  1875.000000  1875.000000   1875.000000
# mean     27.983467         559.73280     0.116830     0.302142      0.435040
# std      26.805860         468.41833     0.165721     0.256789      0.247839
# min       1.000000           7.00000     0.000000     0.000000      0.014963
# 25%      10.000000         302.00000     0.013957     0.079164      0.208437
# 50%      20.000000         456.00000     0.043257     0.243655      0.408451
# 75%      30.000000         658.50000     0.147760     0.473335      0.639441
# max      84.000000        5921.00000     0.925735     0.935385      1.000000
#
#          white_pct      swd_pct      ell_pct  poverty_pct
# count  1875.000000  1875.000000  1875.000000  1875.000000
# mean      0.116964     0.239530     0.141580     0.774975
# std       0.168880     0.157192     0.140997     0.191384
# min       0.000000     0.000000     0.000000     0.052941
# 25%       0.015811     0.166461     0.050651     0.721908
# 50%       0.034783     0.211699     0.102484     0.833919
# 75%       0.139874     0.263433     0.186553     0.908411
# max       0.945137     1.000000     1.000000     0.960000

# %%
# we can also call describe aon a single series:
df.swd_pct.describe()
# Out:
# count    1875.000000
# mean        0.239530
# std         0.157192
# min         0.000000
# 25%         0.166461
# 50%         0.211699
# 75%         0.263433
# max         1.000000
# Name: swd_pct, dtype: float64

# %%
# we can also call the corr() method to show correclations between columns
# we will take out "district" from this data because the district number
# is categorical -- not the measure of a value

# correlations close to 1 or negative one show high correlations
# closer to zero items are not closely correlated
data = df.drop(columns=["district"])
data.corr()
# Out:
# /tmp/ipykernel_21356/792112253.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   total_enrollment  asian_pct  black_pct  hispanic_pct  \
# total_enrollment          1.000000   0.351473  -0.246863     -0.113577
# asian_pct                 0.351473   1.000000  -0.450517     -0.370280
# black_pct                -0.246863  -0.450517   1.000000     -0.421608
# hispanic_pct             -0.113577  -0.370280  -0.421608      1.000000
# white_pct                 0.190804   0.214854  -0.447071     -0.397966
# swd_pct                  -0.183169  -0.204568   0.128486      0.059059
# ell_pct                  -0.017371   0.116053  -0.358130      0.451864
# poverty_pct              -0.164646  -0.309208   0.305314      0.496305
#
#                   white_pct   swd_pct   ell_pct  poverty_pct
# total_enrollment   0.190804 -0.183169 -0.017371    -0.164646
# asian_pct          0.214854 -0.204568  0.116053    -0.309208
# black_pct         -0.447071  0.128486 -0.358130     0.305314
# hispanic_pct      -0.397966  0.059059  0.451864     0.496305
# white_pct          1.000000 -0.062842 -0.180826    -0.800583
# swd_pct           -0.062842  1.000000 -0.012036     0.222089
# ell_pct           -0.180826 -0.012036  1.000000     0.353824
# poverty_pct       -0.800583  0.222089  0.353824     1.000000

# %%
# last, we can use styles to make the correlation table easier to read
# note: you need to run this cell to see the colors -- it's get saved without the styled output
corr = data.corr()
# a coolwarm color map will show values in a gradient where -1 is the deepest blue and 1 is deepest red
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_21356/143913075.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <style type="text/css">
# #T_2a717_row0_col0, #T_2a717_row1_col1, #T_2a717_row2_col2, #T_2a717_row3_col3, #T_2a717_row4_col4, #T_2a717_row5_col5, #T_2a717_row6_col6, #T_2a717_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2a717_row0_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_2a717_row0_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2a717_row0_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_2a717_row0_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_2a717_row0_col5, #T_2a717_row4_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2a717_row0_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_2a717_row0_col7, #T_2a717_row7_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_2a717_row1_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_2a717_row1_col2, #T_2a717_row1_col5, #T_2a717_row2_col0, #T_2a717_row2_col1, #T_2a717_row2_col3, #T_2a717_row2_col6, #T_2a717_row4_col2, #T_2a717_row4_col7, #T_2a717_row7_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2a717_row1_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2a717_row1_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_2a717_row1_col6, #T_2a717_row4_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_2a717_row1_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_2a717_row2_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_2a717_row2_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_2a717_row2_col7, #T_2a717_row6_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_2a717_row3_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2a717_row3_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2a717_row3_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_2a717_row3_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2a717_row3_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2a717_row3_col6 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_2a717_row3_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_2a717_row4_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_2a717_row4_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_2a717_row4_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_2a717_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2a717_row5_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_2a717_row5_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2a717_row5_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_2a717_row5_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_2a717_row5_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_2a717_row5_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_2a717_row6_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_2a717_row6_col1 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_2a717_row6_col2, #T_2a717_row7_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_2a717_row6_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_2a717_row6_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_2a717_row6_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_2a717_row7_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_2a717_row7_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_2a717_row7_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_2a717_row7_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# </style>
# <table id="T_2a717">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a717_level0_col0" class="col_heading level0 col0" >total_enrollment</th>
#       <th id="T_2a717_level0_col1" class="col_heading level0 col1" >asian_pct</th>
#       <th id="T_2a717_level0_col2" class="col_heading level0 col2" >black_pct</th>
#       <th id="T_2a717_level0_col3" class="col_heading level0 col3" >hispanic_pct</th>
#       <th id="T_2a717_level0_col4" class="col_heading level0 col4" >white_pct</th>
#       <th id="T_2a717_level0_col5" class="col_heading level0 col5" >swd_pct</th>
#       <th id="T_2a717_level0_col6" class="col_heading level0 col6" >ell_pct</th>
#       <th id="T_2a717_level0_col7" class="col_heading level0 col7" >poverty_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a717_level0_row0" class="row_heading level0 row0" >total_enrollment</th>
#       <td id="T_2a717_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2a717_row0_col1" class="data row0 col1" >0.351473</td>
#       <td id="T_2a717_row0_col2" class="data row0 col2" >-0.246863</td>
#       <td id="T_2a717_row0_col3" class="data row0 col3" >-0.113577</td>
#       <td id="T_2a717_row0_col4" class="data row0 col4" >0.190804</td>
#       <td id="T_2a717_row0_col5" class="data row0 col5" >-0.183169</td>
#       <td id="T_2a717_row0_col6" class="data row0 col6" >-0.017371</td>
#       <td id="T_2a717_row0_col7" class="data row0 col7" >-0.164646</td>
#     </tr>
#     <tr>
#       <th id="T_2a717_level0_row1" class="row_heading level0 row1" >asian_pct</th>
#       <td id="T_2a717_row1_col0" class="data row1 col0" >0.351473</td>
#       <td id="T_2a717_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2a717_row1_col2" class="data row1 col2" >-0.450517</td>
#       <td id="T_2a717_row1_col3" class="data row1 col3" >-0.370280</td>
#       <td id="T_2a717_row1_col4" class="data row1 col4" >0.214854</td>
#       <td id="T_2a717_row1_col5" class="data row1 col5" >-0.204568</td>
#       <td id="T_2a717_row1_col6" class="data row1 col6" >0.116053</td>
#       <td id="T_2a717_row1_col7" class="data row1 col7" >-0.309208</td>
#     </tr>
#     <tr>
#       <th id="T_2a717_level0_row2" class="row_heading level0 row2" >black_pct</th>
#       <td id="T_2a717_row2_col0" class="data row2 col0" >-0.246863</td>
#       <td id="T_2a717_row2_col1" class="data row2 col1" >-0.450517</td>
#       <td id="T_2a717_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2a717_row2_col3" class="data row2 col3" >-0.421608</td>
#       <td id="T_2a717_row2_col4" class="data row2 col4" >-0.447071</td>
#       <td id="T_2a717_row2_col5" class="data row2 col5" >0.128486</td>
#       <td id="T_2a717_row2_col6" class="data row2 col6" >-0.358130</td>
#       <td id="T_2a717_row2_col7" class="data row2 col7" >0.305314</td>
#     </tr>
#     <tr>
#       <th id="T_2a717_level0_row3" class="row_heading level0 row3" >hispanic_pct</th>
#       <td id="T_2a717_row3_col0" class="data row3 col0" >-0.113577</td>
#       <td id="T_2a717_row3_col1" class="data row3 col1" >-0.370280</td>
#       <td id="T_2a717_row3_col2" class="data row3 col2" >-0.421608</td>
#       <td id="T_2a717_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2a717_row3_col4" class="data row3 col4" >-0.397966</td>
#       <td id="T_2a717_row3_col5" class="data row3 col5" >0.059059</td>
#       <td id="T_2a717_row3_col6" class="data row3 col6" >0.451864</td>
#       <td id="T_2a717_row3_col7" class="data row3 col7" >0.496305</td>
#     </tr>
#     <tr>
#       <th id="T_2a717_level0_row4" class="row_heading level0 row4" >white_pct</th>
#       <td id="T_2a717_row4_col0" class="data row4 col0" >0.190804</td>
#       <td id="T_2a717_row4_col1" class="data row4 col1" >0.214854</td>
#       <td id="T_2a717_row4_col2" class="data row4 col2" >-0.447071</td>
#       <td id="T_2a717_row4_col3" class="data row4 col3" >-0.397966</td>
#       <td id="T_2a717_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2a717_row4_col5" class="data row4 col5" >-0.062842</td>
#       <td id="T_2a717_row4_col6" class="data row4 col6" >-0.180826</td>
#       <td id="T_2a717_row4_col7" class="data row4 col7" >-0.800583</td>
#     </tr>
#     <tr>
#       <th id="T_2a717_level0_row5" class="row_heading level0 row5" >swd_pct</th>
#       <td id="T_2a717_row5_col0" class="data row5 col0" >-0.183169</td>
#       <td id="T_2a717_row5_col1" class="data row5 col1" >-0.204568</td>
#       <td id="T_2a717_row5_col2" class="data row5 col2" >0.128486</td>
#       <td id
