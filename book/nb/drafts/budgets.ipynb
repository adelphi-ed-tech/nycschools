# %%
import pandas as pd
from nycschools import schools
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from collections import Counter
from itertools import chain


import os

import dotenv
dotenv.load_dotenv()
os.environ.get("CHROME_PATH", None)

# %% [markdown]
# Functions
# =========

# %%
def open_webdriver():

    # don't launch the browser GUI
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--headless')

    # if the environment variables are set, use them
    chrome_path = os.environ.get("CHROME_PATH", None)
    chromedriver_path = os.environ.get("CHROMEDRIVER_PATH", None)
    
    if chrome_path:
        chrome_options.binary_location = chrome_path
    if chromedriver_path:
        print("using driver")
        s = Service(chromedriver_path)
        return webdriver.Chrome(service=s, options=chrome_options)

    return webdriver.Chrome(options=chrome_options)

def fix_cols(data, sections, dbn):


    col_map = {
        'title': 'item',
        'assignment': 'item',
        'organizational category': 'item',
        'total': 'item',
        'total.1': 'item',
        'grand total': 'item',
        'type of class/service': 'service'
    }


    data = data.copy()
    
    for i, section in enumerate(sections):
        data[i]["category"] = section
        data[i].columns = [c.lower() for c in data[i].columns]
        data[i].rename(columns=col_map, inplace=True)
        school_col = [c for c in data[i].columns if c.lower().startswith(dbn.lower())]
        if len(school_col) > 0:
            data[i].rename(columns={school_col[0]: 'item'}, inplace=True)
    return data


def get_budgets(dbn, ay, driver):

    url = f"https://www.nycenet.edu/offices/d_chanc_oper/budget/dbor/galaxy/galaxybudgetsummaryto/default.aspx?DDBSSS_INPUT={dbn[2:]}"

    driver.get(url)
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')

    sections = [section.get_text().strip() for section in soup.select('.TO_Section')]
    data = pd.read_html(html)
    data = fix_cols(data, sections, dbn)

    for i in range(len(data)):
        data[i] = data[i].loc[:, ~data[i].columns.duplicated()]

    data = pd.concat(data, ignore_index=True)
    data["dbn"] = dbn
    data["ay"] = ay

    return data

def batch_budgets(dbns, ay, driver):
    budgets = []
    not_found = []
    for dbn in dbns:
        try:
            budgets.append(get_budgets(dbn, ay, driver))
        except ValueError:
            not_found.append(dbn)

    data = pd.concat(budgets)
    data.item = data.item.str.lower()

    return data, not_found

# %% [markdown]
# Single School Test
# ==================

# %%
driver = open_webdriver()
data = get_budgets("13K001", 2022, driver)
driver.quit()
data
# Out:
#                             item  positions        budget
# 0                 HEAD OF SCHOOL        1.0     $ 181,271  \
# 1            ASST HEAD OF SCHOOL        3.0     $ 351,441
# 2               Leadership Total        4.0     $ 532,712
# 3             PARENT COORDINATOR        1.0      $ 50,520
# 4               School Secretary        2.0     $ 126,423
# ..                           ...        ...           ...
# 102         School Funded Copier        NaN       $ 8,940
# 103                Not Available        NaN      $ 29,840
# 104  People Working Partial Year        NaN     $ 143,389
# 105                          NaN       93.0  $ 10,606,323
# 106                          NaN        9.0   $ 1,030,197
#
#                         category grade service subject
# 0                     Leadership   NaN     NaN     NaN  \
# 1                     Leadership   NaN     NaN     NaN
# 2                     Leadership   NaN     NaN     NaN
# 3    Coordinator/Supervisor/Dean   NaN     NaN     NaN
# 4                      Secretary   NaN     NaN     NaN
# ..                           ...   ...     ...     ...
# 102                    Setasides   NaN     NaN     NaN
# 103        Sixth period coverage   NaN     NaN     NaN
# 104  People Working Partial Year   NaN     NaN     NaN
# 105                  School Site   NaN     NaN     NaN
# 106                  School Site   NaN     NaN     NaN
#
#     15k001 - ps 001 the bergen school     dbn    ay
# 0                                 NaN  13K001  2022
# 1                                 NaN  13K001  2022
# 2                                 NaN  13K001  2022
# 3                                 NaN  13K001  2022
# 4                                 NaN  13K001  2022
# ..                                ...     ...   ...
# 102                               NaN  13K001  2022
# 103                               NaN  13K001  2022
# 104                               NaN  13K001  2022
# 105                       Main School  13K001  2022
# 106    Trinity Early Childhood Center  13K001  2022
#
# [107 rows x 10 columns]

# %%
# cols = [d.columns for d in data]
# cols = list(chain(*cols))
# counts = pd.DataFrame(Counter(cols).items(), columns=['header', 'count'])
# counts.sort_values('count', ascending=False)

cols = []
for d in data:
    if isinstance(d, pd.DataFrame):
        cols.append(d.columns)
cols = list(chain(*cols))
counts = pd.DataFrame(Counter(cols).items(), columns=['header', 'count'])

# %% [markdown]
# Batch Budgets
# ==============

# %%
df = schools.load_school_demographics()
df = df[(df.ay == df.ay.max()) & (df.district < 33)]
dbns = df.dbn.values
driver = open_webdriver()
budgets, not_found = batch_budgets(dbns, 2022, driver)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       3 dbns = df.dbn.values
#       4 driver = open_webdriver()
# ----> 5 budgets, not_found = batch_budgets(dbns, 2022, driver)
#       7 driver.quit()
#
# Cell In[5], line 73, in batch_budgets(dbns, ay, driver)
#      71 for dbn in dbns:
#      72     try:
# ---> 73         budgets.append(get_budgets(dbn, ay, driver))
#      74     except ValueError:
#      75         not_found.append(dbn)
#
# Cell In[5], line 50, in get_budgets(dbn, ay, driver)
#      46 def get_budgets(dbn, ay, driver):
#      48     url = f"https://www.nycenet.edu/offices/d_chanc_oper/budget/dbor/galaxy/galaxybudgetsummaryto/default.aspx?DDBSSS_INPUT={dbn[2:]}"
# ---> 50     driver.get(url)
#      51     html = driver.page_source
#      53     soup = BeautifulSoup(html, 'html.parser')
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/GitHub/nycschools/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/anaconda3/lib/python3.8/http/client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File ~/opt/anaconda3/lib/python3.8/http/client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File ~/opt/anaconda3/lib/python3.8/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
budgets.columns
data = budgets.copy()

# update slice of data to set item to the value of "grand total" where grand total is not null
# data.loc[data["grand total"].notnull(), "item"] = data["grand total"]
x = data[data["grand total"].notnull()]
x["item"] = x["grand total"]
data[data["grand total"].notnull()]

# %%
# items = data.item.value_counts()
# x = pd.DataFrame(items)
# x.sort_values("item").head(50)
budgets.to_csv("/opt/nycschools/galaxy.csv", index=False)

# %%
# cols = [d.columns for d in budgets]
# cols = list(chain(*cols))
# counts = pd.DataFrame(Counter(cols).items(), columns=['column', 'count'])
# counts.sort_values('count', ascending=False)
budgets.columns

# %%
# set autoreload
# %load_ext autoreload
from nycschools import budgets

# %%
data, not_found = budgets.get_galaxy_budgets()
len(data)
# Out:
# Error scraping 15K001
# 111745

# %%
budgets.load_galaxy_budgets()
# Out:
#                                     item  positions       budget  \
# 0                         head of school        1.0    $ 183,162
# 1                        ap - special ed        1.0    $ 144,323
# 2                       ap - supervision        2.0    $ 289,124
# 3                       leadership total        4.0    $ 616,609
# 4                                   dean        1.0     $ 98,459
# ...                                  ...        ...          ...
# 3757  office temp services - contractual        NaN    $ 165,000
# 3758                  supplies - general        NaN     $ 43,820
# 3759                           textbooks        NaN     $ 24,599
# 3760                          otps total        NaN    $ 276,645
# 3761                         main school       22.0  $ 2,539,821
#
#                          category subject service     dbn    ay grade
# 0                      Leadership     NaN     NaN  27Q302  2022   NaN
# 1                      Leadership     NaN     NaN  27Q302  2022   NaN
# 2                      Leadership     NaN     NaN  27Q302  2022   NaN
# 3                      Leadership     NaN     NaN  27Q302  2022   NaN
# 4     Coordinator/Supervisor/Dean     NaN     NaN  27Q302  2022   NaN
# ...                           ...     ...     ...     ...   ...   ...
# 3757                         OTPS     NaN     NaN  02M150  2022   NaN
# 3758                         OTPS     NaN     NaN  02M150  2022   NaN
# 3759                         OTPS     NaN     NaN  02M150  2022   NaN
# 3760                         OTPS     NaN     NaN  02M150  2022   NaN
# 3761                  School Site     NaN     NaN  02M150  2022   NaN
#
# [3762 rows x 9 columns]
