# %%
from nycschools import nysed

df = nysed.load_nys_nysed()
df.head()
# Out:
#    index                  school_name         beds      category exam  grade  \
# 0      0  ALBANY CITY SCHOOL DISTRICT  10100010000  All Students  ela      3
# 1      1  ALBANY CITY SCHOOL DISTRICT  10100010000        Female  ela      3
# 2      2  ALBANY CITY SCHOOL DISTRICT  10100010000          Male  ela      3
# 3      3  ALBANY CITY SCHOOL DISTRICT  10100010000       Not SWD  ela      3
# 4      4  ALBANY CITY SCHOOL DISTRICT  10100010000           SWD  ela      3
#
#    test_year  number_tested  total_enrollment  number_not_tested  ...  \
# 0       2021            305               632                327  ...
# 1       2021            167               324                157  ...
# 2       2021            138               308                170  ...
# 3       2021            263               536                273  ...
# 4       2021             42                96                 54  ...
#
#    level_2_pct  level_3_n  level_3_pct  level_4_n  level_4_pct  level_3_4_pct  \
# ...
