# %%
import pandas as pd
from IPython.display import Markdown as md
from school_data import schools, ui, exams

# %%
df = schools.load_school_demographics()

# %%
ela_df = exams.load_ela()
ela_df
# Out:
#           dbn       grade  year      category  number_tested  \
# 0      01M015           3  2013  All Students             27
# 7      01M015           4  2013  All Students             20
# 14     01M015           5  2013  All Students             24
# 21     01M015  All Grades  2013  All Students             71
# 32826  01M015           3  2013       Not SWD             19
# ...       ...         ...   ...           ...            ...
# 5326   84X730           3  2019  All Students             51
# 5333   84X730           4  2019  All Students             49
# 5340   84X730           5  2019  All Students             53
# 5341   84X730           6  2019  All Students            113
# 5348   84X730  All Grades  2019  All Students            266
#
#        mean_scale_score  level_1_n  level_1_pct  level_2_n  level_2_pct  \
# 0            289.296295       14.0    51.851852       11.0    40.740742
# 7            277.649994        8.0    40.000000       11.0    55.000000
# ...

# %%
math_df = exams.load_ela()
math_df
# Out:
#           dbn       grade  year      category  number_tested  \
# 0      01M015           3  2013  All Students             27
# 7      01M015           4  2013  All Students             20
# 14     01M015           5  2013  All Students             24
# 21     01M015  All Grades  2013  All Students             71
# 32826  01M015           3  2013       Not SWD             19
# ...       ...         ...   ...           ...            ...
# 5326   84X730           3  2019  All Students             51
# 5333   84X730           4  2019  All Students             49
# 5340   84X730           5  2019  All Students             53
# 5341   84X730           6  2019  All Students            113
# 5348   84X730  All Grades  2019  All Students            266
#
#        mean_scale_score  level_1_n  level_1_pct  level_2_n  level_2_pct  \
# 0            289.296295       14.0    51.851852       11.0    40.740742
# 7            277.649994        8.0    40.000000       11.0    55.000000
# ...
